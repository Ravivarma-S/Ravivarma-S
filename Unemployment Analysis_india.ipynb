# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px

# %%
dfval = pd.read_csv('Downloads/Unemployment in India.csv')
dfval.tail(100)
# Out:
#          Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 668      Sikkim   31-05-2020    Monthly                             19.75
# 669      Sikkim   30-06-2020    Monthly                              2.63
# 670  Tamil Nadu   31-05-2019    Monthly                              0.89
# 671  Tamil Nadu   30-06-2019    Monthly                              1.56
# 672  Tamil Nadu   31-07-2019    Monthly                              3.18
# ..          ...          ...        ...                               ...
# 763         NaN          NaN        NaN                               NaN
# 764         NaN          NaN        NaN                               NaN
# 765         NaN          NaN        NaN                               NaN
# 766         NaN          NaN        NaN                               NaN
# 767         NaN          NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# ...

# %%
dfval.shape
# Out:
# (768, 7)

# %%
dfval.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
dfval.isnull().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
dfval.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
dfval.describe()
# Out:
#        Estimated Unemployment Rate (%)  Estimated Employed  \
# count                       740.000000        7.400000e+02
# mean                         11.787946        7.204460e+06
# std                          10.721298        8.087988e+06
# min                           0.000000        4.942000e+04
# 25%                           4.657500        1.190404e+06
# 50%                           8.350000        4.744178e+06
# 75%                          15.887500        1.127549e+07
# max                          76.740000        4.577751e+07
#
#        Estimated Labour Participation Rate (%)
# count                               740.000000
# mean                                 42.630122
# std                                   8.111094
# min                                  13.330000
# 25%                                  38.062500
# 50%                                  41.160000
# 75%                                  45.505000
# max                                  72.570000

# %%
#returns the no of unique values in each column
dfval.nunique()
# Out:
# Region                                       28
#  Date                                        14
#  Frequency                                    2
#  Estimated Unemployment Rate (%)            624
#  Estimated Employed                         740
#  Estimated Labour Participation Rate (%)    626
# Area                                          2
# dtype: int64

# %%
#removes the row where all the values are null
dfval = dfval.dropna(how='all')
dfval
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %% [markdown]
# Estimated Amount of Employment in India at each state

# %%
plt.figure(figsize=(10,12))
plt.title("Estimated Employement rate")
sns.histplot(x = ' Estimated Employed' , hue = 'Region' , data = dfval)
plt.show()

# %% [markdown]
# Estimated Amount of unemployment in India at each state

# %%
plt.figure(figsize=(10,12))
plt.title("Estimated unemployement rate")
sns.histplot(x = ' Estimated Unemployment Rate (%)' , hue = 'Region' , data = dfval)
plt.show()

# %% [markdown]
# Now we will create a dashboard for seeing the unemployment rate in different regions of india

# %%
import plotly.express as px
unemployement = dfval[['Region',' Estimated Unemployment Rate (%)','Area']]
figure = px.sunburst(dfval,path=['Region','Area'],values = ' Estimated Unemployment Rate (%)',width =1000,height=1000,title = "Unemployement in India")
figure.show()

# %% [raw]
# conclusion:
#            1. Tripura has the most unemployement rate of overall 793.81%  in both urban and rural
#            2. Sikkim has the least unemployement rate of  overall 123.24% in both urban and rural
